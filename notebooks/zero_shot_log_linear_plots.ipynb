# %%
import os
import pickle
import json
import matplotlib.pyplot as plt
from scipy import stats

from matplotlib import rcParams
import numpy as np
import matplotlib.ticker as ticker
import seaborn as sns
from scipy.stats import pearsonr

rcParams["font.family"] = "serif"
rcParams["grid.linestyle"] = ':'
rcParams["xtick.direction"] = 'in'
rcParams["ytick.direction"] = 'in'
rcParams["legend.fontsize"] = 11
rcParams["axes.labelsize"] = 18
rcParams["axes.titlesize"] = 20
rcParams["xtick.labelsize"] = 15
rcParams["ytick.labelsize"] = 15

# %%
plot_file_template = './plots/log-linear-all-datasets-plot-counttype_{}_prompttype_{}_ptdataset_{}_model_{}.pkl'

# %% [markdown]
# ## CC-3M

# %%
prompt_type = 'ensemble'
image_search_type = 'rampp0.7'
text_search_type = 'lemmatized'
integrated_search_type = 'integrated_rampp0.7'
pt_dataset = 'cc3m'

# image-search
rn50_image_res = pickle.load(open(plot_file_template.format(image_search_type, prompt_type, pt_dataset, 'RN50'), 'rb'))
vitb16_image_res = pickle.load(open(plot_file_template.format(image_search_type, prompt_type, pt_dataset, 'ViT-B-16'), 'rb'))

# text-search
rn50_text_res = pickle.load(open(plot_file_template.format(text_search_type, prompt_type, pt_dataset, 'RN50'), 'rb'))
vitb16_text_res = pickle.load(open(plot_file_template.format(text_search_type, prompt_type, pt_dataset, 'ViT-B-16'), 'rb'))

# integrated-search
rn50_integrated_res = pickle.load(open(plot_file_template.format(integrated_search_type, prompt_type, pt_dataset, 'RN50'), 'rb'))
vitb16_integrated_res = pickle.load(open(plot_file_template.format(integrated_search_type, prompt_type, pt_dataset, 'ViT-B-16'), 'rb'))

# %%
plt.figure(figsize=(6.4, 4.8))
# image-search

rn50_corr, sig1 = pearsonr(np.log(rn50_image_res['exp_bins'][1:-1]), rn50_image_res['cum_means'][1:-1])
vitb16_corr, sig2 = pearsonr(np.log(vitb16_image_res['exp_bins'][1:-1]), vitb16_image_res['cum_means'][1:-1])

add1 = '**' if sig1<0.05 else ''
add2 = '**' if sig2<0.05 else ''

plt.figure()
plt.plot(rn50_image_res['exp_bins'][1:-1], rn50_image_res['cum_means'][1:-1], marker='o', linestyle='solid', label=f'RN50, $\\rho$={rn50_corr:.2f}'+add1, alpha=0.6, markersize=8, linewidth=2, c='royalblue')
plt.plot(vitb16_image_res['exp_bins'][1:-1], vitb16_image_res['cum_means'][1:-1], marker='s', linestyle='solid', label=f'ViT-B-16, $\\rho$={vitb16_corr:.2f}'+add2, alpha=0.6, markersize=8, linewidth=2, c='forestgreen')
plt.xlabel('Pre-training Concept Frequency')
plt.ylabel('Avg. Zero-Shot Accuracy')
plt.xscale('log')
plt.xlim(0, 9*10**5)
# sns.despine(trim=True, offset=5)
plt.legend(loc='lower right', fontsize=16)

# plt.text(0.05, 0.95, f'RN50 Pearson r={rn50_corr:.2f}', transform=plt.gca().transAxes, color='royalblue')
# plt.text(0.05, 0.90, f'ViT-B-16 Pearson r={vitb16_corr:.2f}', transform=plt.gca().transAxes, color='forestgreen')

# plt.title('Accuracies vs PCF for CC-3M\n(Image-search)')
plt.grid()
plt.gca().xaxis.set_major_locator(ticker.LogLocator(base=10.0, numticks=12))
plt.gca().xaxis.set_minor_locator(ticker.LogLocator(base=10.0, subs=np.arange(1.0, 10.0) * 0.1, numticks=12))
# plt.savefig('./plots/eccv-paper-cc3m-zero-shot-log-linear-plot-image-queried-search.png', dpi=500, bbox_inches='tight', transparent=True)
# plt.savefig('./plots/eccv-paper-cc3m-zero-shot-log-linear-plot-image-queried-search-simple.png', dpi=500, bbox_inches='tight', transparent=True)
plt.savefig('./plots/eccv-paper-cc3m-zero-shot-log-linear-plot-image-queried-search-ensemble.png', dpi=500, bbox_inches='tight', transparent=True)
# Out:
# /tmp/ipykernel_939777/3269915348.py:16: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0, 9*10**5)

# %%
plt.figure(figsize=(6.4, 4.8))
#text-search

rn50_corr, sig1 = pearsonr(np.log(rn50_text_res['exp_bins'][1:-1]), rn50_text_res['cum_means'][1:-1])
vitb16_corr, sig2 = pearsonr(np.log(vitb16_text_res['exp_bins'][1:-1]), vitb16_text_res['cum_means'][1:-1])

add1 = '**' if sig1<0.05 else ''
add2 = '**' if sig2<0.05 else ''

plt.plot(rn50_text_res['exp_bins'][1:-1], rn50_text_res['cum_means'][1:-1], marker='o', linestyle='solid', label=f'RN50, $\\rho$={rn50_corr:.2f}'+add1, alpha=0.6, markersize=8, linewidth=2, c='royalblue')
plt.plot(vitb16_text_res['exp_bins'][1:-1], vitb16_text_res['cum_means'][1:-1], marker='s', linestyle='solid', label=f'ViT-B-16, $\\rho$={vitb16_corr:.2f}'+add2, alpha=0.6, markersize=8, linewidth=2, c='forestgreen')
plt.xlabel('Pre-training Concept Frequency')
plt.ylabel('Avg. Zero-Shot Accuracy')
plt.xscale('log')
plt.xlim(0, 1*10**5)
# sns.despine(trim=True, offset=5)
plt.legend(loc='lower right', fontsize=16)
# plt.title('Accuracies vs PCF for CC-3M\n(Text-search)')
plt.grid()
plt.gca().xaxis.set_major_locator(ticker.LogLocator(base=10.0, numticks=12))
plt.gca().xaxis.set_minor_locator(ticker.LogLocator(base=10.0, subs=np.arange(1.0, 10.0) * 0.1, numticks=12))
# plt.savefig('./plots/eccv-paper-cc3m-zero-shot-log-linear-plot-text-queried-search.png', dpi=500, bbox_inches='tight', transparent=True)
# plt.savefig('./plots/eccv-paper-cc3m-zero-shot-log-linear-plot-text-queried-search-simple.png', dpi=500, bbox_inches='tight', transparent=True)
plt.savefig('./plots/eccv-paper-cc3m-zero-shot-log-linear-plot-text-queried-search-ensemble.png', dpi=500, bbox_inches='tight', transparent=True)
# Out:
# /tmp/ipykernel_939777/1587291423.py:15: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0, 1*10**5)

# %%
plt.figure(figsize=(6.4, 4.8))
#integrated-search

rn50_corr, sig1 = pearsonr(np.log(rn50_integrated_res['exp_bins'][1:-1]), rn50_integrated_res['cum_means'][1:-1])
vitb16_corr, sig2 = pearsonr(np.log(vitb16_integrated_res['exp_bins'][1:-1]), vitb16_integrated_res['cum_means'][1:-1])

add1 = '**' if sig1<0.05 else ''
add2 = '**' if sig2<0.05 else ''

plt.plot(rn50_integrated_res['exp_bins'][1:-1], rn50_integrated_res['cum_means'][1:-1], 'o-', label=f'RN50, $\\rho$={rn50_corr:.2f}'+add1, alpha=0.6, markersize=8, linewidth=2, c='royalblue')
plt.plot(vitb16_integrated_res['exp_bins'][1:-1], vitb16_integrated_res['cum_means'][1:-1], 's-', label=f'ViT-B-16, $\\rho$={vitb16_corr:.2f}'+add2, alpha=0.6, markersize=8, linewidth=2, c='forestgreen')
plt.xlabel('Pre-training Concept Frequency')
plt.ylabel('Avg. Zero-Shot Accuracy')
plt.xscale('log')
plt.xlim(0, 7*10**4)
# sns.despine(trim=True, offset=5)
plt.legend(loc='lower right', fontsize=16)

# plt.title('Accuracies vs PCF for CC-3M\n(Integrated-search)')
plt.grid()
plt.gca().xaxis.set_major_locator(ticker.LogLocator(base=10.0, numticks=12))
plt.gca().xaxis.set_minor_locator(ticker.LogLocator(base=10.0, subs=np.arange(1.0, 10.0) * 0.1, numticks=12))
# plt.savefig('./plots/eccv-paper-cc3m-zero-shot-log-linear-plot-integrated-queried-search.png', dpi=500, bbox_inches='tight', transparent=True)
# plt.savefig('./plots/eccv-paper-cc3m-zero-shot-log-linear-plot-integrated-queried-search-simple.png', dpi=500, bbox_inches='tight', transparent=True)
plt.savefig('./plots/eccv-paper-cc3m-zero-shot-log-linear-plot-integrated-queried-search-ensemble.png', dpi=500, bbox_inches='tight', transparent=True)
# Out:
# /tmp/ipykernel_939777/2354717431.py:15: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0, 7*10**4)

# %% [markdown]
# ## CC-12M

# %%
prompt_type = 'ensemble'
image_search_type = 'rampp0.7'
text_search_type = 'lemmatized'
pt_dataset = 'cc12m'
integrated_search_type = 'integrated_rampp0.7'

# image-search
rn50_image_res = pickle.load(open(plot_file_template.format(image_search_type, prompt_type, pt_dataset, 'RN50'), 'rb'))
vitb16_image_res = pickle.load(open(plot_file_template.format(image_search_type, prompt_type, pt_dataset, 'ViT-B-16'), 'rb'))

# text-search
rn50_text_res = pickle.load(open(plot_file_template.format(text_search_type, prompt_type, pt_dataset, 'RN50'), 'rb'))
vitb16_text_res = pickle.load(open(plot_file_template.format(text_search_type, prompt_type, pt_dataset, 'ViT-B-16'), 'rb'))

# integrated-search
rn50_integrated_res = pickle.load(open(plot_file_template.format(integrated_search_type, prompt_type, pt_dataset, 'RN50'), 'rb'))
vitb16_integrated_res = pickle.load(open(plot_file_template.format(integrated_search_type, prompt_type, pt_dataset, 'ViT-B-16'), 'rb'))

# %%
plt.figure(figsize=(6.4, 4.8))
# image-search

rn50_corr, sig1 = pearsonr(np.log(rn50_image_res['exp_bins'][1:-1]), rn50_image_res['cum_means'][1:-1])
vitb16_corr, sig2 = pearsonr(np.log(vitb16_image_res['exp_bins'][1:-1]), vitb16_image_res['cum_means'][1:-1])

add1 = '**' if sig1<0.05 else ''
add2 = '**' if sig2<0.05 else ''

plt.plot(rn50_image_res['exp_bins'][1:-1], rn50_image_res['cum_means'][1:-1], marker='o', linestyle='solid', label=f'RN50, $\\rho$={rn50_corr:.2f}'+add1, alpha=0.6, markersize=8, linewidth=2, c='royalblue')
plt.plot(vitb16_image_res['exp_bins'][1:-1], vitb16_image_res['cum_means'][1:-1], marker='s', linestyle='solid', label=f'ViT-B-16, $\\rho$={vitb16_corr:.2f}'+add2, alpha=0.6, markersize=8, linewidth=2, c='forestgreen')
plt.xlabel('Pre-training Concept Frequency')
plt.ylabel('Avg. Zero-Shot Accuracy')
plt.xscale('log')
plt.xlim(0, 3*10**6)
# sns.despine(trim=True, offset=5)
plt.legend(loc='lower right', fontsize=16)

# plt.title('Accuracies vs PCF for CC-12M\n(Image-search)')
plt.grid()
plt.gca().xaxis.set_major_locator(ticker.LogLocator(base=10.0, numticks=12))
plt.gca().xaxis.set_minor_locator(ticker.LogLocator(base=10.0, subs=np.arange(1.0, 10.0) * 0.1, numticks=12))
# plt.savefig('./plots/eccv-paper-cc12m-zero-shot-log-linear-plot-image-queried-search.png', dpi=500, bbox_inches='tight', transparent=True)
# plt.savefig('./plots/eccv-paper-cc12m-zero-shot-log-linear-plot-image-queried-search-simple.png', dpi=500, bbox_inches='tight', transparent=True)
plt.savefig('./plots/eccv-paper-cc12m-zero-shot-log-linear-plot-image-queried-search-ensemble.png', dpi=500, bbox_inches='tight', transparent=True)
# Out:
# /tmp/ipykernel_939777/257277531.py:15: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0, 3*10**6)

# %%
plt.figure(figsize=(6.4, 4.8))
#text-search

rn50_corr, sig1 = pearsonr(np.log(rn50_text_res['exp_bins'][1:-1]), rn50_text_res['cum_means'][1:-1])
vitb16_corr, sig2 = pearsonr(np.log(vitb16_text_res['exp_bins'][1:-1]), vitb16_text_res['cum_means'][1:-1])

add1 = '**' if sig1<0.05 else ''
add2 = '**' if sig2<0.05 else ''

plt.plot(rn50_text_res['exp_bins'][1:-1], rn50_text_res['cum_means'][1:-1], marker='o', linestyle='solid', label=f'RN50, $\\rho$={rn50_corr:.2f}'+add1, alpha=0.6, markersize=8, linewidth=2, c='royalblue')
plt.plot(vitb16_text_res['exp_bins'][1:-1], vitb16_text_res['cum_means'][1:-1], marker='s', linestyle='solid', label=f'ViT-B-16, $\\rho$={vitb16_corr:.2f}'+add2, alpha=0.6, markersize=8, linewidth=2, c='forestgreen')
plt.xlabel('Pre-training Concept Frequency')
plt.ylabel('Avg. Zero-Shot Accuracy')
plt.xscale('log')
plt.xlim(0, 2*10**5)
# sns.despine(trim=True, offset=5)
plt.legend(loc='lower right', fontsize=16)

# plt.title('Accuracies vs PCF for CC-12M\n(Text-search)')
plt.grid()
plt.gca().xaxis.set_major_locator(ticker.LogLocator(base=10.0, numticks=12))
plt.gca().xaxis.set_minor_locator(ticker.LogLocator(base=10.0, subs=np.arange(1.0, 10.0) * 0.1, numticks=12))
# plt.savefig('./plots/eccv-paper-cc12m-zero-shot-log-linear-plot-text-queried-search.png', dpi=500, bbox_inches='tight', transparent=True)
# plt.savefig('./plots/eccv-paper-cc12m-zero-shot-log-linear-plot-text-queried-search-simple.png', dpi=500, bbox_inches='tight', transparent=True)
plt.savefig('./plots/eccv-paper-cc12m-zero-shot-log-linear-plot-text-queried-search-ensemble.png', dpi=500, bbox_inches='tight', transparent=True)
# Out:
# /tmp/ipykernel_939777/607844415.py:15: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0, 2*10**5)

# %%
plt.figure(figsize=(6.4, 4.8))
#integrated-search

rn50_corr, sig1 = pearsonr(np.log(rn50_integrated_res['exp_bins'][1:-1]), rn50_integrated_res['cum_means'][1:-1])
vitb16_corr, sig2 = pearsonr(np.log(vitb16_integrated_res['exp_bins'][1:-1]), vitb16_integrated_res['cum_means'][1:-1])

add1 = '**' if sig1<0.05 else ''
add2 = '**' if sig2<0.05 else ''

plt.plot(rn50_integrated_res['exp_bins'][1:-1], rn50_integrated_res['cum_means'][1:-1], 'o-', label=f'RN50, $\\rho$={rn50_corr:.2f}'+add1, alpha=0.6, markersize=8, linewidth=2, c='royalblue')
plt.plot(vitb16_integrated_res['exp_bins'][1:-1], vitb16_integrated_res['cum_means'][1:-1], 's-', label=f'ViT-B-16, $\\rho$={vitb16_corr:.2f}'+add2, alpha=0.6, markersize=8, linewidth=2, c='forestgreen')
plt.xlabel('Pre-training Concept Frequency')
plt.ylabel('Avg. Zero-Shot Accuracy')
plt.xscale('log')
plt.xlim(0, 1*10**5)
# sns.despine(trim=True, offset=5)
plt.legend(loc='lower right', fontsize=16)

# plt.title('Accuracies vs PCF for CC-12M\n(Integrated-search)')
plt.grid()
plt.gca().xaxis.set_major_locator(ticker.LogLocator(base=10.0, numticks=12))
plt.gca().xaxis.set_minor_locator(ticker.LogLocator(base=10.0, subs=np.arange(1.0, 10.0) * 0.1, numticks=12))
# plt.savefig('./plots/eccv-paper-cc12m-zero-shot-log-linear-plot-integrated-queried-search.png', dpi=500, bbox_inches='tight', transparent=True)
# plt.savefig('./plots/eccv-paper-cc12m-zero-shot-log-linear-plot-integrated-queried-search-simple.png', dpi=500, bbox_inches='tight', transparent=True)
plt.savefig('./plots/eccv-paper-cc12m-zero-shot-log-linear-plot-integrated-queried-search-ensemble.png', dpi=500, bbox_inches='tight', transparent=True)
# Out:
# /tmp/ipykernel_939777/1520847379.py:15: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0, 1*10**5)

# %% [markdown]
# ## LAION400M

# %%
prompt_type = 'ensemble'
image_search_type = 'rampp0.7'
text_search_type = 'lemmatized'
integrated_search_type = 'integrated_rampp0.7'
pt_dataset = 'laion400m'

# image-search
# rn50_image_res = pickle.load(open(plot_file_template.format(image_search_type, prompt_type, pt_dataset, 'RN50'), 'rb'))
vitb32_image_res = pickle.load(open(plot_file_template.format(image_search_type, prompt_type, pt_dataset, 'ViT-B-32'), 'rb'))
vitb16_image_res = pickle.load(open(plot_file_template.format(image_search_type, prompt_type, pt_dataset, 'ViT-B-16'), 'rb'))
vitl14_image_res = pickle.load(open(plot_file_template.format(image_search_type, prompt_type, pt_dataset, 'ViT-L-14'), 'rb'))

# text-search
# rn50_text_res = pickle.load(open(plot_file_template.format(text_search_type, prompt_type, pt_dataset, 'RN50'), 'rb'))
vitb32_text_res = pickle.load(open(plot_file_template.format(text_search_type, prompt_type, pt_dataset, 'ViT-B-32'), 'rb'))
vitb16_text_res = pickle.load(open(plot_file_template.format(text_search_type, prompt_type, pt_dataset, 'ViT-B-16'), 'rb'))
vitl14_text_res = pickle.load(open(plot_file_template.format(text_search_type, prompt_type, pt_dataset, 'ViT-L-14'), 'rb'))

# text-search
# rn50_integrated_res = pickle.load(open(plot_file_template.format(integrated_search_type, prompt_type, pt_dataset, 'RN50'), 'rb'))
vitb32_integrated_res = pickle.load(open(plot_file_template.format(integrated_search_type, prompt_type, pt_dataset, 'ViT-B-32'), 'rb'))
vitb16_integrated_res = pickle.load(open(plot_file_template.format(integrated_search_type, prompt_type, pt_dataset, 'ViT-B-16'), 'rb'))
vitl14_integrated_res = pickle.load(open(plot_file_template.format(integrated_search_type, prompt_type, pt_dataset, 'ViT-L-14'), 'rb'))

# %%
plt.figure(figsize=(6.4, 4.8))
# image-search

vitb32_corr, sig1 = pearsonr(np.log(vitb32_image_res['exp_bins'][2:-1]), vitb32_image_res['cum_means'][2:-1])
vitb16_corr, sig2 = pearsonr(np.log(vitb16_image_res['exp_bins'][2:-1]), vitb16_image_res['cum_means'][2:-1])
vitl14_corr, sig3 = pearsonr(np.log(vitl14_image_res['exp_bins'][2:-1]), vitl14_image_res['cum_means'][2:-1])

add1 = '**' if sig1<0.05 else ''
add2 = '**' if sig2<0.05 else ''
add3 = '**' if sig3<0.05 else ''

plt.plot(vitb32_image_res['exp_bins'][2:-1], vitb32_image_res['cum_means'][2:-1], marker='o', linestyle='solid', label=f'ViT-B-32, $\\rho$={vitb32_corr:.2f}'+add1, alpha=0.6, markersize=8, linewidth=2, c='royalblue')
plt.plot(vitb16_image_res['exp_bins'][2:-1], vitb16_image_res['cum_means'][2:-1], marker='d', linestyle='solid', label=f'ViT-B-16, $\\rho$={vitb16_corr:.2f}'+add2, alpha=0.6, markersize=8, linewidth=2, c='indianred')
plt.plot(vitl14_image_res['exp_bins'][2:-1], vitl14_image_res['cum_means'][2:-1], marker='s', linestyle='solid', label=f'ViT-L-14, $\\rho$={vitl14_corr:.2f}'+add3, alpha=0.6, markersize=8, linewidth=2, c='forestgreen')
plt.xlabel('Pre-training Concept Frequency')
plt.ylabel('Avg. Zero-Shot Accuracy')
plt.xscale('log')
plt.xlim(0, 9*10**7)
# sns.despine(trim=True, offset=5)
plt.legend(loc='lower right', fontsize=15)

# plt.title('Accuracies vs PCF for LAION-400M\n(Image-search)')
plt.grid()
plt.gca().xaxis.set_major_locator(ticker.LogLocator(base=10.0, numticks=12))
plt.gca().xaxis.set_minor_locator(ticker.LogLocator(base=10.0, subs=np.arange(1.0, 10.0) * 0.1, numticks=12))
# plt.savefig('./plots/eccv-paper-laion400m-zero-shot-log-linear-plot-image-queried-search.png', dpi=500, bbox_inches='tight', transparent=True)
# plt.savefig('./plots/eccv-paper-laion400m-zero-shot-log-linear-plot-image-queried-search-simple.png', dpi=500, bbox_inches='tight', transparent=True)
plt.savefig('./plots/eccv-paper-laion400m-zero-shot-log-linear-plot-image-queried-search-ensemble.png', dpi=500, bbox_inches='tight', transparent=True)
# Out:
# /tmp/ipykernel_2221394/2740936841.py:18: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0, 9*10**7)

# %%
plt.figure(figsize=(6.4, 4.8))
# text-search

vitb32_corr, sig1 = pearsonr(np.log(vitb32_text_res['exp_bins'][2:-1]), vitb32_text_res['cum_means'][2:-1])
vitb16_corr, sig2 = pearsonr(np.log(vitb16_text_res['exp_bins'][2:-1]), vitb16_text_res['cum_means'][2:-1])
vitl14_corr, sig3 = pearsonr(np.log(vitl14_text_res['exp_bins'][2:-1]), vitl14_text_res['cum_means'][2:-1])

add1 = '**' if sig1<0.05 else ''
add2 = '**' if sig2<0.05 else ''
add3 = '**' if sig3<0.05 else ''

plt.plot(vitb32_text_res['exp_bins'][2:-1], vitb32_text_res['cum_means'][2:-1], marker='o', linestyle='solid', label=f'ViT-B-32, $\\rho$={vitb32_corr:.2f}'+add1, alpha=0.6, markersize=8, linewidth=2, c='royalblue')
plt.plot(vitb16_text_res['exp_bins'][2:-1], vitb16_text_res['cum_means'][2:-1], marker='d', linestyle='solid', label=f'ViT-B-16, $\\rho$={vitb16_corr:.2f}'+add2, alpha=0.6, markersize=8, linewidth=2, c='indianred')
plt.plot(vitl14_text_res['exp_bins'][2:-1], vitl14_text_res['cum_means'][2:-1], marker='s', linestyle='solid', label=f'ViT-L-14, $\\rho$={vitl14_corr:.2f}'+add3, alpha=0.6, markersize=8, linewidth=2, c='forestgreen')

plt.xlabel('Pre-training Concept Frequency')
plt.ylabel('Avg. Zero-Shot Accuracy')
plt.xscale('log')
plt.xlim(0, 3*10**6)
# sns.despine(trim=True, offset=5)
plt.legend(loc='best', fontsize=15)
# plt.title('Accuracies vs PCF for LAION-400M\n(Text-search)')
plt.grid()
plt.gca().xaxis.set_major_locator(ticker.LogLocator(base=10.0, numticks=12))
plt.gca().xaxis.set_minor_locator(ticker.LogLocator(base=10.0, subs=np.arange(1.0, 10.0) * 0.1, numticks=12))
# plt.savefig('./plots/eccv-paper-laion400m-zero-shot-log-linear-plot-text-queried-search.png', dpi=500, bbox_inches='tight', transparent=True)
# plt.savefig('./plots/eccv-paper-laion400m-zero-shot-log-linear-plot-text-queried-search-simple.png', dpi=500, bbox_inches='tight', transparent=True)
plt.savefig('./plots/eccv-paper-laion400m-zero-shot-log-linear-plot-text-queried-search-ensemble.png', dpi=500, bbox_inches='tight', transparent=True)
# Out:
# /tmp/ipykernel_2221394/509202208.py:19: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0, 3*10**6)

# %%
plt.figure(figsize=(6.4, 4.8))
# integrated-search

vitb32_corr, sig1 = pearsonr(np.log(vitb32_integrated_res['exp_bins'][2:-1]), vitb32_integrated_res['cum_means'][2:-1])
vitb16_corr, sig2 = pearsonr(np.log(vitb16_integrated_res['exp_bins'][2:-1]), vitb16_integrated_res['cum_means'][2:-1])
vitl14_corr, sig3 = pearsonr(np.log(vitl14_integrated_res['exp_bins'][2:-1]), vitl14_integrated_res['cum_means'][2:-1])

add1 = '**' if sig1<0.05 else ''
add2 = '**' if sig2<0.05 else ''
add3 = '**' if sig3<0.05 else ''

plt.plot(vitb32_integrated_res['exp_bins'][2:-1], vitb32_integrated_res['cum_means'][2:-1], marker='o', linestyle='solid', label=f'ViT-B-32, $\\rho$={vitb32_corr:.2f}'+add1, alpha=0.6, markersize=8, linewidth=2, c='royalblue')
plt.plot(vitb16_integrated_res['exp_bins'][2:-1], vitb16_integrated_res['cum_means'][2:-1], marker='d', linestyle='solid', label=f'ViT-B-16, $\\rho$={vitb16_corr:.2f}'+add2, alpha=0.6, markersize=8, linewidth=2, c='indianred')
plt.plot(vitl14_integrated_res['exp_bins'][2:-1], vitl14_integrated_res['cum_means'][2:-1], marker='s', linestyle='solid', label=f'ViT-L-14, $\\rho$={vitl14_corr:.2f}'+add3, alpha=0.6, markersize=8, linewidth=2, c='forestgreen')

plt.xlabel('Pre-training Concept Frequency')
plt.ylabel('Avg. Zero-Shot Accuracy')
plt.xscale('log')
plt.xlim(0, 3*10**6)
# sns.despine(trim=True, offset=5)
plt.legend(loc='best', fontsize=15)
# plt.title('Accuracies vs PCF for LAION-400M\n(Text-search)')
plt.grid()
plt.gca().xaxis.set_major_locator(ticker.LogLocator(base=10.0, numticks=12))
plt.gca().xaxis.set_minor_locator(ticker.LogLocator(base=10.0, subs=np.arange(1.0, 10.0) * 0.1, numticks=12))
# plt.savefig('./plots/eccv-paper-laion400m-zero-shot-log-linear-plot-text-queried-search.png', dpi=500, bbox_inches='tight', transparent=True)
# plt.savefig('./plots/eccv-paper-laion400m-zero-shot-log-linear-plot-text-queried-search-simple.png', dpi=500, bbox_inches='tight', transparent=True)
plt.savefig('./plots/eccv-paper-laion400m-zero-shot-log-linear-plot-integrated-queried-search-ensemble.png', dpi=500, bbox_inches='tight', transparent=True)
# Out:
# /tmp/ipykernel_2221394/2083417004.py:19: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0, 3*10**6)

# %% [markdown]
# ## YFCC15M

# %%
prompt_type = 'ensemble'
image_search_type = 'rampp0.7'
text_search_type = 'lemmatized'
pt_dataset = 'yfcc15m'
integrated_search_type = 'integrated_rampp0.7'

# image-search
rn50_image_res = pickle.load(open(plot_file_template.format(image_search_type, prompt_type, pt_dataset, 'RN50'), 'rb'))
rn101_image_res = pickle.load(open(plot_file_template.format(image_search_type, prompt_type, pt_dataset, 'RN101'), 'rb'))
vitb16_image_res = pickle.load(open(plot_file_template.format(image_search_type, prompt_type, pt_dataset, 'ViT-B-16'), 'rb'))

# text-search
rn50_text_res = pickle.load(open(plot_file_template.format(text_search_type, prompt_type, pt_dataset, 'RN50'), 'rb'))
rn101_text_res = pickle.load(open(plot_file_template.format(text_search_type, prompt_type, pt_dataset, 'RN101'), 'rb'))
vitb16_text_res = pickle.load(open(plot_file_template.format(text_search_type, prompt_type, pt_dataset, 'ViT-B-16'), 'rb'))

# integrated-search
rn50_integrated_res = pickle.load(open(plot_file_template.format(integrated_search_type, prompt_type, pt_dataset, 'RN50'), 'rb'))
rn101_integrated_res = pickle.load(open(plot_file_template.format(integrated_search_type, prompt_type, pt_dataset, 'RN101'), 'rb'))
vitb16_integrated_res = pickle.load(open(plot_file_template.format(integrated_search_type, prompt_type, pt_dataset, 'ViT-B-16'), 'rb'))

# %%
plt.figure(figsize=(6.4, 4.8))
# image-search

rn50_corr, sig1 = pearsonr(np.log(rn50_image_res['exp_bins'][1:-1]), rn50_image_res['cum_means'][1:-1])
rn101_corr, sig2 = pearsonr(np.log(rn101_image_res['exp_bins'][1:-1]), rn101_image_res['cum_means'][1:-1])
vitb16_corr, sig3 = pearsonr(np.log(vitb16_image_res['exp_bins'][1:-1]), vitb16_image_res['cum_means'][1:-1])

add1 = '**' if sig1<0.05 else ''
add2 = '**' if sig2<0.05 else ''
add3 = '**' if sig3<0.05 else ''

plt.plot(rn50_image_res['exp_bins'][1:-1], rn50_image_res['cum_means'][1:-1], marker='o', linestyle='solid', label=f'RN50, $\\rho$={rn50_corr:.2f}'+add1, alpha=0.6, markersize=8, linewidth=2, c='royalblue')
plt.plot(rn101_image_res['exp_bins'][1:-1], rn101_image_res['cum_means'][1:-1], marker='d', linestyle='solid', label=f'RN101, $\\rho$={rn101_corr:.2f}'+add2, alpha=0.6, markersize=8, linewidth=2, c='indianred')
plt.plot(vitb16_image_res['exp_bins'][1:-1], vitb16_image_res['cum_means'][1:-1], marker='s', linestyle='solid', label=f'ViT-B-16, $\\rho$={vitb16_corr:.2f}'+add3, alpha=0.6, markersize=8, linewidth=2, c='forestgreen')
plt.xlabel('Pre-training Concept Frequency')
plt.ylabel('Avg. Zero-Shot Accuracy')
plt.xscale('log')
plt.xlim(0, 9*10**6)
# sns.despine(trim=True, offset=5)
plt.legend(loc='lower right', fontsize=15)

# plt.title('Accuracies vs PCF for YFCC-15M\n(Image-search)')
plt.grid()
plt.gca().xaxis.set_major_locator(ticker.LogLocator(base=10.0, numticks=12))
plt.gca().xaxis.set_minor_locator(ticker.LogLocator(base=10.0, subs=np.arange(1.0, 10.0) * 0.1, numticks=12))
# plt.savefig('./plots/eccv-paper-zero-shot-yfcc15m-log-linear-plot-image-queried-search.png', dpi=500, bbox_inches='tight', transparent=True)
# plt.savefig('./plots/eccv-paper-zero-shot-yfcc15m-log-linear-plot-image-queried-search-simple.png', dpi=500, bbox_inches='tight', transparent=True)
plt.savefig('./plots/eccv-paper-zero-shot-yfcc15m-log-linear-plot-image-queried-search-ensemble.png', dpi=500, bbox_inches='tight', transparent=True)
# Out:
# /tmp/ipykernel_939777/713486076.py:18: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0, 9*10**6)

# %%
plt.figure(figsize=(6.4, 4.8))
# text-search

rn50_corr, sig1 = pearsonr(np.log(rn50_text_res['exp_bins'][1:-1]), rn50_text_res['cum_means'][1:-1])
rn101_corr, sig2 = pearsonr(np.log(rn101_text_res['exp_bins'][1:-1]), rn101_text_res['cum_means'][1:-1])
vitb16_corr, sig3 = pearsonr(np.log(vitb16_text_res['exp_bins'][1:-1]), vitb16_text_res['cum_means'][1:-1])

add1 = '**' if sig1<0.05 else ''
add2 = '**' if sig2<0.05 else ''
add3 = '**' if sig3<0.05 else ''

plt.plot(rn50_text_res['exp_bins'][1:-1], rn50_text_res['cum_means'][1:-1], marker='o', linestyle='solid', label=f'RN50, $\\rho$={rn50_corr:.2f}'+add1, alpha=0.6, markersize=8, linewidth=2, c='royalblue')
plt.plot(rn101_text_res['exp_bins'][1:-1], rn101_text_res['cum_means'][1:-1], marker='d', linestyle='solid', label=f'RN101, $\\rho$={rn101_corr:.2f}'+add2, alpha=0.6, markersize=8, linewidth=2, c='indianred')
plt.plot(vitb16_text_res['exp_bins'][1:-1], vitb16_text_res['cum_means'][1:-1], marker='s', linestyle='solid', label=f'ViT-B-16, $\\rho$={vitb16_corr:.2f}'+add3, alpha=0.6, markersize=8, linewidth=2, c='forestgreen')
plt.xlabel('Pre-training Concept Frequency')
plt.ylabel('Avg. Zero-Shot Accuracy')
plt.xscale('log')
plt.xlim(0, 1*10**6)
# sns.despine(trim=True, offset=5)
plt.legend(loc='lower right', fontsize=15)

# plt.title('Accuracies vs PCF for YFCC-15M\n(Text-search)')
plt.grid()
plt.gca().xaxis.set_major_locator(ticker.LogLocator(base=10.0, numticks=12))
plt.gca().xaxis.set_minor_locator(ticker.LogLocator(base=10.0, subs=np.arange(1.0, 10.0) * 0.1, numticks=12))
# plt.savefig('./plots/eccv-paper-yfcc15m-zero-shot-log-linear-plot-text-queried-search.png', dpi=500, bbox_inches='tight', transparent=True)
# plt.savefig('./plots/eccv-paper-yfcc15m-zero-shot-log-linear-plot-text-queried-search-simple.png', dpi=500, bbox_inches='tight', transparent=True)
plt.savefig('./plots/eccv-paper-yfcc15m-zero-shot-log-linear-plot-text-queried-search-ensemble.png', dpi=500, bbox_inches='tight', transparent=True)
# Out:
# /tmp/ipykernel_939777/80354026.py:18: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0, 1*10**6)

# %%
plt.figure(figsize=(6.4, 4.8))
#integrated-search

rn50_corr, sig1 = pearsonr(np.log(rn50_integrated_res['exp_bins'][1:-1]), rn50_integrated_res['cum_means'][1:-1])
rn101_corr, sig2 = pearsonr(np.log(rn101_integrated_res['exp_bins'][1:-1]), rn101_integrated_res['cum_means'][1:-1])
vitb16_corr, sig3 = pearsonr(np.log(vitb16_integrated_res['exp_bins'][1:-1]), vitb16_integrated_res['cum_means'][1:-1])

add1 = '**' if sig1<0.05 else ''
add2 = '**' if sig2<0.05 else ''
add3 = '**' if sig3<0.05 else ''

plt.plot(rn50_integrated_res['exp_bins'][1:-1], rn50_integrated_res['cum_means'][1:-1], marker='o', linestyle='solid', label=f'RN50, $\\rho$={rn50_corr:.2f}'+add1, alpha=0.6, markersize=8, linewidth=2, c='royalblue')
plt.plot(rn101_integrated_res['exp_bins'][1:-1], rn101_integrated_res['cum_means'][1:-1], marker='d', linestyle='solid', label=f'RN101, $\\rho$={rn101_corr:.2f}'+add2, alpha=0.6, markersize=8, linewidth=2, c='indianred')
plt.plot(vitb16_integrated_res['exp_bins'][1:-1], vitb16_integrated_res['cum_means'][1:-1], marker='s', linestyle='solid', label=f'ViT-B-16, $\\rho$={vitb16_corr:.2f}'+add3, alpha=0.6, markersize=8, linewidth=2, c='forestgreen')
plt.xlabel('Pre-training Concept Frequency')
plt.ylabel('Avg. Zero-Shot Accuracy')
plt.xscale('log')
plt.xlim(0, 7*10**4)
# sns.despine(trim=True, offset=5)
plt.legend(loc='lower right', fontsize=15)

# plt.title('Accuracies vs PCF for CC-12M\n(Integrated-search)')
plt.grid()
plt.gca().xaxis.set_major_locator(ticker.LogLocator(base=10.0, numticks=12))
plt.gca().xaxis.set_minor_locator(ticker.LogLocator(base=10.0, subs=np.arange(1.0, 10.0) * 0.1, numticks=12))
# plt.savefig('./plots/eccv-paper-yfcc15m-zero-shot-log-linear-plot-integrated-queried-search.png', dpi=500, bbox_inches='tight', transparent=True)
# plt.savefig('./plots/eccv-paper-yfcc15m-zero-shot-log-linear-plot-integrated-queried-search-simple.png', dpi=500, bbox_inches='tight', transparent=True)
plt.savefig('./plots/eccv-paper-yfcc15m-zero-shot-log-linear-plot-integrated-queried-search-ensemble.png', dpi=500, bbox_inches='tight', transparent=True)
# Out:
# /tmp/ipykernel_939777/270818468.py:18: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0, 7*10**4)

# %% [markdown]
# ## LAION-200M-train-test-sim-normalized

# %%
prompt_type = 'class'
image_search_type = 'rampp0.7'
text_search_type = 'lemmatized'
pt_dataset = 'laion200m_train_test_sim_normalized'
integrated_search_type = 'integrated_rampp0.7'

# image-search
vitb32_image_res = pickle.load(open(plot_file_template.format(image_search_type, prompt_type, pt_dataset, 'ViT-B-32'), 'rb'))

# %%
plt.figure(figsize=(6.4, 4.8))
# image-search

vitb32_corr, sig1 = pearsonr(np.log(vitb32_image_res['exp_bins'][1:-1]), vitb32_image_res['cum_means'][1:-1])

add1 = '**' if sig1<0.05 else ''

# plt.plot(vitb32_image_res['exp_bins'][1:-1], vitb32_image_res['cum_means'][1:-1], marker='o', linestyle='solid', label=f'ViT-B-32, $\\rho$={vitb32_corr:.2f}'+add1, alpha=0.6, markersize=8, linewidth=2, c='royalblue')
plt.plot(vitb32_image_res['exp_bins'][1:-1], vitb32_image_res['cum_means'][1:-1], marker='o', linestyle='solid', label=f'$\\rho$={vitb32_corr:.2f}'+add1, alpha=0.6, markersize=8, linewidth=2, c='royalblue')
plt.xlabel('Pre-training Concept Frequency')
plt.ylabel('Avg. Zero-Shot Accuracy')
plt.xscale('log')
plt.xlim(0, 3*10**7)
# sns.despine(trim=True, offset=5)
plt.legend(loc='lower right', fontsize=15)

# plt.title('Accuracies vs PCF for YFCC-15M\n(Image-search)')
plt.grid()
plt.gca().xaxis.set_major_locator(ticker.LogLocator(base=10.0, numticks=12))
plt.gca().xaxis.set_minor_locator(ticker.LogLocator(base=10.0, subs=np.arange(1.0, 10.0) * 0.1, numticks=12))
plt.savefig('./plots/eccv-paper-zero-shot-laion200m-train-test-sim-normalized-log-linear-plot-image-queried-search.png', dpi=500, bbox_inches='tight', transparent=True)
# Out:
# /tmp/ipykernel_1609038/2972924552.py:13: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0, 3*10**7)

# %% [markdown]
# ## SynthCLIP

# %%
prompt_type = 'class'
image_search_type = 'rampp0.7'
text_search_type = 'lemmatized'
pt_dataset = 'synthci30m'
integrated_search_type = 'integrated_rampp0.7'

# image-search
vitb16_image_res = pickle.load(open(plot_file_template.format(image_search_type, prompt_type, pt_dataset, 'ViT-B-16'), 'rb'))

# text-search
vitb16_text_res = pickle.load(open(plot_file_template.format(text_search_type, prompt_type, pt_dataset, 'ViT-B-16'), 'rb'))

# integrated-search
vitb16_integrated_res = pickle.load(open(plot_file_template.format(integrated_search_type, prompt_type, pt_dataset, 'ViT-B-16'), 'rb'))

# %%
plt.figure(figsize=(6.4, 4.8))
# image-search

vitb16_corr, sig1 = pearsonr(np.log(vitb16_image_res['exp_bins'][0:-4]), vitb16_image_res['cum_means'][0:-4])

add1 = '**' if sig1<0.05 else ''

plt.plot(vitb16_image_res['exp_bins'][0:-4], vitb16_image_res['cum_means'][0:-4], marker='o', linestyle='solid', label=f'ViT-B-16, $\\rho$={vitb16_corr:.2f}'+add1, alpha=0.6, markersize=8, linewidth=2, c='royalblue')
plt.xlabel('Pre-training Concept Frequency')
plt.ylabel('Avg. Zero-Shot Accuracy')
plt.xscale('log')
plt.xlim(0, 6*10**4)
# sns.despine(trim=True, offset=5)
plt.legend(loc='lower right', fontsize=15)

# plt.title('Accuracies vs PCF for YFCC-15M\n(Image-search)')
plt.grid()
plt.gca().xaxis.set_major_locator(ticker.LogLocator(base=10.0, numticks=12))
plt.gca().xaxis.set_minor_locator(ticker.LogLocator(base=10.0, subs=np.arange(1.0, 10.0) * 0.1, numticks=12))
plt.savefig('./plots/eccv-paper-zero-shot-synthci30m-log-linear-plot-image-queried-search.png', dpi=500, bbox_inches='tight', transparent=True)
# Out:
# /tmp/ipykernel_1609038/1295373216.py:12: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0, 6*10**4)

# %%
plt.figure(figsize=(6.4, 4.8))
# text-search

vitb16_corr, sig1 = pearsonr(np.log(vitb16_text_res['exp_bins'][0:-4]), vitb16_text_res['cum_means'][0:-4])

add1 = '**' if sig1<0.05 else ''

plt.plot(vitb16_text_res['exp_bins'][0:-4], vitb16_text_res['cum_means'][0:-4], marker='o', linestyle='solid', label=f'ViT-B-16, $\\rho$={vitb16_corr:.2f}'+add1, alpha=0.6, markersize=8, linewidth=2, c='royalblue')
plt.xlabel('Pre-training Concept Frequency')
plt.ylabel('Avg. Zero-Shot Accuracy')
plt.xscale('log')
plt.xlim(0, 2*10**4)
# sns.despine(trim=True, offset=5)
plt.legend(loc='lower right', fontsize=15)

# plt.title('Accuracies vs PCF for YFCC-15M\n(Image-search)')
plt.grid()
plt.gca().xaxis.set_major_locator(ticker.LogLocator(base=10.0, numticks=12))
plt.gca().xaxis.set_minor_locator(ticker.LogLocator(base=10.0, subs=np.arange(1.0, 10.0) * 0.1, numticks=12))
plt.savefig('./plots/eccv-paper-zero-shot-synthci30m-log-linear-plot-text-queried-search.png', dpi=500, bbox_inches='tight', transparent=True)
# Out:
# /tmp/ipykernel_1609038/238646488.py:12: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0, 2*10**4)

# %%
plt.figure(figsize=(6.4, 4.8))
# integrated-search

vitb16_corr, sig1 = pearsonr(np.log(vitb16_integrated_res['exp_bins'][0:-4]), vitb16_integrated_res['cum_means'][0:-4])

add1 = '**' if sig1<0.05 else ''

plt.plot(vitb16_integrated_res['exp_bins'][0:-4], vitb16_integrated_res['cum_means'][0:-4], marker='o', linestyle='solid', label=f'ViT-B-16, $\\rho$={vitb16_corr:.2f}'+add1, alpha=0.6, markersize=8, linewidth=2, c='royalblue')
plt.xlabel('Pre-training Concept Frequency')
plt.ylabel('Avg. Zero-Shot Accuracy')
plt.xscale('log')
plt.xlim(0, 2*10**4)
# sns.despine(trim=True, offset=5)
plt.legend(loc='lower right', fontsize=15)

# plt.title('Accuracies vs PCF for YFCC-15M\n(Image-search)')
plt.grid()
plt.gca().xaxis.set_major_locator(ticker.LogLocator(base=10.0, numticks=12))
plt.gca().xaxis.set_minor_locator(ticker.LogLocator(base=10.0, subs=np.arange(1.0, 10.0) * 0.1, numticks=12))
plt.savefig('./plots/eccv-paper-zero-shot-synthci30m-log-linear-plot-integrated-queried-search.png', dpi=500, bbox_inches='tight', transparent=True)
# Out:
# /tmp/ipykernel_1609038/2978876204.py:12: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0, 2*10**4)

# %%
plt.figure(figsize=(6.4, 4.8))
# search

vitb16_image_corr, sig1 = pearsonr(np.log(vitb16_image_res['exp_bins'][0:-4]), vitb16_image_res['cum_means'][0:-4])
add1_image = '**' if sig1<0.05 else ''

vitb16_text_corr, sig1 = pearsonr(np.log(vitb16_text_res['exp_bins'][0:-4]), vitb16_text_res['cum_means'][0:-4])
add1_text = '**' if sig1<0.05 else ''

vitb16_integrated_corr, sig1 = pearsonr(np.log(vitb16_integrated_res['exp_bins'][0:-4]), vitb16_integrated_res['cum_means'][0:-4])
add1_integrated = '**' if sig1<0.05 else ''

plt.plot(vitb16_image_res['exp_bins'][0:-4], vitb16_image_res['cum_means'][0:-4], marker='o', linestyle='solid', label=f'image-only-search, $\\rho$={vitb16_image_corr:.2f}'+add1_image, alpha=0.6, markersize=8, linewidth=2, c='royalblue')
plt.plot(vitb16_text_res['exp_bins'][0:-4], vitb16_text_res['cum_means'][0:-4], marker='s', linestyle='dashed', label=f'text-only-search, $\\rho$={vitb16_text_corr:.2f}'+add1_text, alpha=0.6, markersize=8, linewidth=2, c='indianred')
plt.plot(vitb16_integrated_res['exp_bins'][0:-4], vitb16_integrated_res['cum_means'][0:-4], marker='d', linestyle='dotted', label=f'image-text-search, $\\rho$={vitb16_integrated_corr:.2f}'+add1_integrated, alpha=0.6, markersize=8, linewidth=2, c='forestgreen')

plt.xlabel('Pre-training Concept Frequency')
plt.ylabel('Avg. Zero-Shot Accuracy')
plt.xscale('log')
plt.xlim(0, 6*10**4)
# sns.despine(trim=True, offset=5)
plt.legend(loc='upper left', fontsize=11)

# plt.title('Accuracies vs PCF for YFCC-15M\n(Image-search)')
plt.grid()
plt.gca().xaxis.set_major_locator(ticker.LogLocator(base=10.0, numticks=12))
plt.gca().xaxis.set_minor_locator(ticker.LogLocator(base=10.0, subs=np.arange(1.0, 10.0) * 0.1, numticks=12))
plt.savefig('./plots/eccv-paper-zero-shot-synthci30m-log-linear-plot-all-queried-search.png', dpi=500, bbox_inches='tight', transparent=True)
# Out:
# /tmp/ipykernel_1609038/168094320.py:20: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0, 6*10**4)
